# %%
class new_client:
    
     def policy(self):
            print("please choose ur profile name apt to ur policy holder name.")
            h=input("please choose ur profile name: ")
       
            c=["1.)one year plan","2.)two year plan","3.)third year plan"]
            print("welcome",h,"to our insurance policy")
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~********~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("please follow further steps",h)
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~********~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("choose ur plan")
            for i in c:
                print(i)
            print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~********~~~~~~~~~~~~~~~~~~~~~~~~~~")

            e=input(" please enter here ur plan")
            if(e=="1"):
                d=["1.)1L plan","2.)2L plan","3.)5L plan"]
                for i in d:
                    print(i)
                e1=input("enter ur type of mode:-")
                if(e1=="1"):
                    print("you want to pay 1L Plan mode for six month is 8,333 + bonus 100 will added for every successful months.")
                elif(e1=="2"):
                    print("you want to pay 2L Plan mode for six month is 16,666 + bonus 100 will added for every successful months.")
                elif(e1=="3"):
                    print("you want to pay 5L Plan mode for six month is 41,666 + bonus 100 will added for every successful months.")
                else:
                    print("enter valid plan.")

                print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~********~~~~~~~~~~~~~~~~~~~~~~~~~~")

                print("enjoy ur plan and benefits.")


import re
print("~~~~~~~~~~~~~~~~~~~~~~~WELCOME TO SR INSURANCE POLICY~~~~~~~~~~~~~~~~~~~~~~~~")
class old_client():
    def sasi(self):
        
        
        a=input("enter a name:")
        while(len(a)):
            if True:
                print("welcome to our health insurance policy",a)
                break
            else:
                pass
        
        c=input("enter the phone number:")
        m=re.fullmatch('[6-9]\d{9}',c)
        if m!=None:
            print("valid no")
            ur_id=input("enter ur id:")
            s=re.fullmatch('\d{6}',ur_id)
            if s!=None:
                print("valid id")
                f=int(input("enter amount paid from ur date of starting to till now:  "))
                m=int(input("successful months: "))
                tax=100
                if True:
                    print("ur insurance amount + bonus is",f+(tax*m))
                    
                    print("please consult ur agent for further details.")
                    
                    
            else:       
                print("worng id")
        else:
            print("please check ur number")
            
get=input("are u old or new user : ")
if(get=="old" or get=="OLD"):
    
    a=old_client()
    a.sasi()
elif(get=="new" or get=="NEW"):
    b=new_client()   
    b.policy()
else:
    pass
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~WELCOME TO SR INSURANCE POLICY~~~~~~~~~~~~~~~~~~~~~~~~
